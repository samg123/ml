# %% [markdown]
# Test script to perfom detection of beer bottles

# %%
import sklearn as sk
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import skimage
from skimage import io

# %%
filename = './bottles/broad.JPG'
broad = io.imread(filename)

# %%
broad.size/3e6
# Out:
# 7.990272

# %%
plt.imshow(broad)
